# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahsaniss/Pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
results={
    'name':['Ahsan','Hanzala','kashif'],
    'results':[67,56,66]
}

# %%
df=pd.DataFrame(results)

# %%
df
# Out:
#       name  results
# 0    Ahsan       67
# 1  Hanzala       56
# 2   kashif       66

# %%
df.to_csv("results.csv")

# %% [markdown]
# Print without  index

# %%
print(df.to_string(index=False))
# Out:
#    name  results
#   Ahsan       67
# Hanzala       56
#  kashif       66

# %% [markdown]
# .loc vs .iloc in pandas
# 🔹 .loc (label-based indexing)
#
# Used to access rows and columns by labels (names).
#
# Includes the end index when slicing.
#
# Accepts:
#
# Row/column labels ('A', 'B', etc.)
#
# Boolean arrays (for filtering)

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Ahsan", "Ali", "Sara"],
    "age": [21, 25, 30]
}, index=["x", "y", "z"])

# Select row with index label 'y'
print(df.loc["y"])

# Select multiple rows with labels
print(df.loc[["x", "z"]])

# Select rows by label range (inclusive of 'z')
print(df.loc["x":"z"])
# Out:
# name    Ali
# age      25
# Name: y, dtype: object
#     name  age
# x  Ahsan   21
# z   Sara   30
#     name  age
# x  Ahsan   21
# y    Ali   25
# z   Sara   30

# %%
# Select the second row (index position 1)
print(df.iloc[1])

# Select the first and last row
print(df.iloc[[0, 2]])

# Select rows by position range (exclusive of 2)
print(df.iloc[0:2])
# Out:
# name    Ali
# age      25
# Name: y, dtype: object
#     name  age
# x  Ahsan   21
# z   Sara   30
#     name  age
# x  Ahsan   21
# y    Ali   25

# %%
s=pd.Series([1,2,3,np.nan,45,5])

# %%
s
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4    45.0
# 5     5.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
new_dates = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
new_dates
# Out:
#                    A         B         C         D
# 2013-01-01 -0.083364  1.385191  0.056459  1.351376
# 2013-01-02  2.498163  0.652834 -1.347541  2.379506
# 2013-01-03  0.939212 -0.699345  0.785494  0.541061
# 2013-01-04  0.584670  0.849405 -1.999022  0.471411
# 2013-01-05  0.593665 -0.259278  3.933445 -0.492234
# 2013-01-06  0.424870 -0.726132  0.189568  0.052403

# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library:
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions:
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
print("Python version",sys.version)
print("pandas version",pd.__version__)
# Out:
# Python version 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# pandas version 2.2.2

# %%
df=pd.read_csv("/content/AirQualityUCI.csv")

# %%
df.head()
# Out:
#                                                                                                             Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;
# 10/03/2004;18.00.00;2            6;1360;150;11                 9;1046;166;1056;113;1692;1268;13 6;48 9;0                                                7578;;
# 10/03/2004;19.00.00;2;1292;112;9 4;955;103;1174;92;1559;972;13 3;47                             7;0  7255;;                                                NaN
# 10/03/2004;20.00.00;2            2;1402;88;9                   0;939;131;1140;114;1555;1074;11  9;54 0;0                                                7502;;
# 10/03/2004;21.00.00;2            2;1376;80;9                   2;948;172;1092;122;1584;1203;11  0;60 0;0                                                7867;;
# 10/03/2004;22.00.00;1            6;1272;51;6                   5;836;131;1205;116;1490;1110;11  2;59 6;0                                                7888;;
